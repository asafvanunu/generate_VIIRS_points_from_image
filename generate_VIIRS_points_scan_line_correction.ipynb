# %% [markdown]
# # Generate VIIRS points
#
# **Name:** Asaf Vanunu
# **Date:** August 21, 2024
# **step:** 1
#
# ## Description
# This script takes VIIRS fire product and create VIIRS shapefile points while taking into account duplicated fire events resulting from the VIIRS bowtie effect.

# %% [markdown]
# * Load libraries

# %%
import os
import geopandas as gpd
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import shapely.geometry
import GOES_VIIRS_tools
from rasterio.plot import show

# %% [markdown]
# * First we will set a path for VIIRS data

# %%
VIIRS_fire_path = "F:\\VIIRS_data\\VIIRS_fire"
VIIRS_files = [os.path.join(VIIRS_fire_path, f) for f in os.listdir(VIIRS_fire_path) if f.endswith('.nc')] ## get all the VIIRS files

# %%
def conf_to_str(conf):
    """This function converts the confidence value to a string

    Args:
        conf (int): The confidence value

    Returns:
        str: the string representation of the confidence value
    """
    if conf == 7:
        return "l"
    elif conf == 8:
        return "n"
    elif conf == 9:
        return "h"

# %% [markdown]
# * We will need to create a function that generates VIIRS points just from the fire file

# %%
def generate_VIIRS_points(VIIRS_fire_file_path):
    """This function generates a geodataframe of the VIIRS fire data from VIIRS NetCDF file.

    Args:
        VIIRS_fire_file_path (str): Full path to the VIIRS NetCDF file.
    """
    confidences_names = ["l", "n", "h"]
    VIIRS = xr.open_dataset(VIIRS_fire_file_path) ## open the VIIRS file
    number_of_fire_pixels = len(VIIRS["FP_latitude"].values) ## get the number of fire pixels
    VIIRS_file_name = os.path.basename(VIIRS_fire_file_path) ## get the file name
    VIIRS_file_name_list = np.repeat(VIIRS_file_name, number_of_fire_pixels) ## repeat the file name
    VIIRS_unique_date = VIIRS_file_name.split(".")[1] ## get the unique date, example: 'A2022152'
    VIIRS_unique_date = np.repeat(VIIRS_unique_date, number_of_fire_pixels) ## repeat the unique date
    VIIRS_time = GOES_VIIRS_tools.generate_VIIRS_time_from_image(VIIRS_fire_path=VIIRS_fire_file_path,
                                                                 type_of_date="time")
    VIIRS_time_list = np.repeat(VIIRS_time, number_of_fire_pixels) ## get the unique time. example: '09:06'
    VIIRS_time_split = VIIRS_time.split(":") ## split the time
    VIIRS_unique_time = f"{VIIRS_time_split[0]}{VIIRS_time_split[1]}" ## get the unique time. example: "0906"
    VIIRS_unique_time = np.repeat(VIIRS_unique_time, number_of_fire_pixels) ## repeat the unique time
    VIIRS_date = GOES_VIIRS_tools.generate_VIIRS_time_from_image(VIIRS_fire_path=VIIRS_fire_file_path,
                                                                 type_of_date="date") ## get the unique date. format: '2021-06-01'
    VIIRS_date = np.repeat(VIIRS_date, number_of_fire_pixels) ## repeat the unique date
    VIIRS_date_time = GOES_VIIRS_tools.generate_VIIRS_time_from_image(VIIRS_fire_path=VIIRS_fire_file_path,
                                                                      type_of_date="date_time") ## get the unique date time format: '2021-06-01 09:06'
    VIIRS_date_time = np.repeat(VIIRS_date_time, number_of_fire_pixels) ## repeat the unique date time
    VIIRS_day_night = VIIRS.attrs['DayNightFlag'] ## get the day night flag
    VIIRS_day_night = np.repeat(VIIRS_day_night, number_of_fire_pixels) ## repeat the day night flag
    
    ####### Now we will set the array variables ########
    
    VIIRS_lat = VIIRS["FP_latitude"].values ## get the latitude values
    VIIRS_lon = VIIRS["FP_longitude"].values ## get the longitude values
    VIIRS_fire_pixels = VIIRS["FP_confidence"].values ## get the fire pixels
    VIIRS_fire_pixels_name = list(map(conf_to_str, VIIRS_fire_pixels)) ## get the fire pixels names 
    VIIRS_scan_line = VIIRS["FP_line"].values ## get the scan line
    VIIRS_azimuth_angle = VIIRS["FP_ViewZenAng"].values ## get the azimuth angle
    VIIRS_grid_sample = VIIRS["FP_sample"].values ## get the grid sample
    
    ######## Now we will create the geodataframe ########
    VIIRS_dict = {"latitude": VIIRS_lat, "longitude": VIIRS_lon,
                  "Fire_file": VIIRS_file_name_list,
                  "Unique_date": VIIRS_unique_date,
                  "Unique_time": VIIRS_unique_time,
                  "DATE": VIIRS_date,
                  "TIME": VIIRS_time_list,
                  "DATE_TIME": VIIRS_date_time,
                  "fire_pixel_confidence": VIIRS_fire_pixels,
                  "fire_pixel_confidence_str": VIIRS_fire_pixels_name,
                  "scan_line": VIIRS_scan_line,
                  "grid_sample": VIIRS_grid_sample,
                  "View_Zenith_Angle": VIIRS_azimuth_angle,
                  "night/day": VIIRS_day_night}
    VIIRS_df = pd.DataFrame(VIIRS_dict) ## create a dataframe
    
    gdf_VIIRS = gpd.GeoDataFrame(
        VIIRS_df, geometry=gpd.points_from_xy(VIIRS_df.longitude, VIIRS_df.latitude), crs="EPSG:4326") ## create a geodataframe
    
    return gdf_VIIRS

# %% [markdown]
# * Now we will create a function to remove duplicated fire events resulting from the VIIRS bowtie effect
# * In addition it will remove low confidence fire events

# %%
def remove_duplicate_VIIRS_fires(VIIRS_gdf, buffer_size=300, scan_line_diff=3):
    """This function removes duplicated VIIRS fire pixels by creating a buffer around the fire pixel and removing all the fire pixels that are within the buffer.

    Args:
        VIIRS_gdf (GeoDataFrame): a VIIRS GeoDataFrame that contains the fire pixels
        buffer_size (int, optional): The size of the buffer. Defaults to 300.
        scan_line_diff (int, optional): The difference between scan lines .Defaults to 3.
    """
    fire_points_to_remove_id = [] ## create an empty list to store the fire points to remove
    NAD_1983_CRS = "ESRI:102008" ## For accurate distance calculations we need to use a projected coordinate system
    VIIRS_gdf = VIIRS_gdf.to_crs(NAD_1983_CRS) ## change the coordinate system of the GeoDataFrame
    VIIRS_gdf = VIIRS_gdf[VIIRS_gdf['fire_pixel_confidence'] != 7].reset_index(drop=True) ## remove the low confidence fire pixels
    con_zenith_view = VIIRS_gdf["View_Zenith_Angle"] >= 19 ## create a condition for the view zenith angle of the fire pixels where the view zenith angle is greater than 19
    gdf_filter = VIIRS_gdf[con_zenith_view].reset_index(drop=True) ## apply the condition
    con_zenith_view_no_dup = VIIRS_gdf["View_Zenith_Angle"] < 19 ## create a condition for the view zenith angle of the fire pixels where the view zenith angle is less than 19
    gdf_no_dup = VIIRS_gdf[con_zenith_view_no_dup].reset_index(drop=True) ## apply the condition
    gdf_filter["ID"] = gdf_filter.index ## create an ID column
    
    
    for i in range(len(gdf_filter)): ## loop through all the fire pixels
        fire_point = gdf_filter.iloc[[i]] ## get the fire pixel
        fire_point_id = fire_point["ID"].values[0] ## get the fire pixel ID
        if ~np.isin(fire_point_id, fire_points_to_remove_id): ## If the fire point is not used
            fire_point_scan_line = fire_point["scan_line"].iloc[0] ## get the scan line of the fire pixel
            buffer = fire_point.buffer(buffer_size) ## create a buffer around the fire pixel
            fire_point_buffer = gpd.GeoDataFrame(geometry=buffer, crs=NAD_1983_CRS) ## create a GeoDataFrame from the buffer
            buffer_intersection = gpd.overlay(gdf_filter, fire_point_buffer, how='intersection') ## get the intersection between the buffer and the fire pixels
            diff_con = abs(fire_point_scan_line - buffer_intersection["scan_line"].values.astype(int)) >= scan_line_diff ## create a condition to filter the fire pixels
            buffer_intersection_filter = buffer_intersection[diff_con] ## apply the condition
        
            if len(buffer_intersection_filter) > 0: ## if there are fire pixels in the buffer
                fire_points_to_remove_id.extend(buffer_intersection_filter["ID"].values) ## add the fire pixels in the buffer to the fire points to remove
        
    ## after the loop is done, remove the fire points that are in the fire points to remove list
    VIIRS_gdf_filtered = gdf_filter[~np.isin(gdf_filter["ID"], fire_points_to_remove_id)] ## filter the fire pixels
    VIIRS_gdf_filtered = VIIRS_gdf_filtered.drop(columns=["ID"]) ## drop the ID column
    if len(gdf_no_dup) > 0: ## if there are fire pixels with view zenith angle less than 19
        VIIRS_gdf_filtered = pd.concat([VIIRS_gdf_filtered, gdf_no_dup], ignore_index=True)
        VIIRS_gdf_filtered = VIIRS_gdf_filtered.to_crs("EPSG:4326") ## change the coordinate system back to WGS84
        return VIIRS_gdf_filtered
    else:
        VIIRS_gdf_filtered = VIIRS_gdf_filtered.to_crs("EPSG:4326") ## change the coordinate system back to WGS84
        return VIIRS_gdf_filtered ## return the filtered fire pixels

# %% [markdown]
# * Now we can generate VIIRS points

# %%
VIIRS_points = [] ## create an empty list to store the VIIRS points
for i in range(len(VIIRS_files)): ## loop through all the VIIRS files
    VIIRS_gdf = generate_VIIRS_points(VIIRS_files[i]) ## generate the VIIRS points
    VIIRS_gdf_filtered = remove_duplicate_VIIRS_fires(VIIRS_gdf=VIIRS_gdf, buffer_size=300, scan_line_diff=3) ## remove the duplicated VIIRS fires
    VIIRS_points.append(VIIRS_gdf_filtered) ## append the VIIRS points to the list
    print(f"VIIRS file {i+1} out of {len(VIIRS_files)} processed") ## print the progress
# Out:
# VIIRS file 1 out of 1171 processed
# VIIRS file 2 out of 1171 processed
# VIIRS file 3 out of 1171 processed
# VIIRS file 4 out of 1171 processed
# VIIRS file 5 out of 1171 processed
# VIIRS file 6 out of 1171 processed
# VIIRS file 7 out of 1171 processed
# VIIRS file 8 out of 1171 processed
# VIIRS file 9 out of 1171 processed
# VIIRS file 10 out of 1171 processed
# VIIRS file 11 out of 1171 processed
# VIIRS file 12 out of 1171 processed
# VIIRS file 13 out of 1171 processed
# VIIRS file 14 out of 1171 processed
# VIIRS file 15 out of 1171 processed
# VIIRS file 16 out of 1171 processed
# VIIRS file 17 out of 1171 processed
# VIIRS file 18 out of 1171 processed
# VIIRS file 19 out of 1171 processed
# VIIRS file 20 out of 1171 processed
# VIIRS file 21 out of 1171 processed
# VIIRS file 22 out of 1171 processed
# VIIRS file 23 out of 1171 processed
# VIIRS file 24 out of 1171 processed
# VIIRS file 25 out of 1171 processed
# VIIRS file 26 out of 1171 processed
# VIIRS file 27 out of 1171 processed
# VIIRS file 28 out of 1171 processed
# VIIRS file 29 out of 1171 processed
# VIIRS file 30 out of 1171 processed
# VIIRS file 31 out of 1171 processed
# VIIRS file 32 out of 1171 processed
# VIIRS file 33 out of 1171 processed
# VIIRS file 34 out of 1171 processed
# VIIRS file 35 out of 1171 processed
# VIIRS file 36 out of 1171 processed
# VIIRS file 37 out of 1171 processed
# VIIRS file 38 out of 1171 processed
# VIIRS file 39 out of 1171 processed
# VIIRS file 40 out of 1171 processed
# VIIRS file 41 out of 1171 processed
# VIIRS file 42 out of 1171 processed
# VIIRS file 43 out of 1171 processed
# VIIRS file 44 out of 1171 processed
# VIIRS file 45 out of 1171 processed
# VIIRS file 46 out of 1171 processed
# VIIRS file 47 out of 1171 processed
# VIIRS file 48 out of 1171 processed
# VIIRS file 49 out of 1171 processed
# VIIRS file 50 out of 1171 processed
# VIIRS file 51 out of 1171 processed
# VIIRS file 52 out of 1171 processed
# VIIRS file 53 out of 1171 processed
# VIIRS file 54 out of 1171 processed
# VIIRS file 55 out of 1171 processed
# VIIRS file 56 out of 1171 processed
# VIIRS file 57 out of 1171 processed
# VIIRS file 58 out of 1171 processed
# VIIRS file 59 out of 1171 processed
# VIIRS file 60 out of 1171 processed
# VIIRS file 61 out of 1171 processed
# VIIRS file 62 out of 1171 processed
# VIIRS file 63 out of 1171 processed
# VIIRS file 64 out of 1171 processed
# VIIRS file 65 out of 1171 processed
# VIIRS file 66 out of 1171 processed
# VIIRS file 67 out of 1171 processed
# VIIRS file 68 out of 1171 processed
# VIIRS file 69 out of 1171 processed
# VIIRS file 70 out of 1171 processed
# VIIRS file 71 out of 1171 processed
# VIIRS file 72 out of 1171 processed
# VIIRS file 73 out of 1171 processed
# VIIRS file 74 out of 1171 processed
# VIIRS file 75 out of 1171 processed
# VIIRS file 76 out of 1171 processed
# VIIRS file 77 out of 1171 processed
# VIIRS file 78 out of 1171 processed
# VIIRS file 79 out of 1171 processed
# VIIRS file 80 out of 1171 processed
# VIIRS file 81 out of 1171 processed
# VIIRS file 82 out of 1171 processed
# VIIRS file 83 out of 1171 processed
# VIIRS file 84 out of 1171 processed
# VIIRS file 85 out of 1171 processed
# VIIRS file 86 out of 1171 processed
# VIIRS file 87 out of 1171 processed
# VIIRS file 88 out of 1171 processed
# VIIRS file 89 out of 1171 processed
# VIIRS file 90 out of 1171 processed
# VIIRS file 91 out of 1171 processed
# VIIRS file 92 out of 1171 processed
# VIIRS file 93 out of 1171 processed
# VIIRS file 94 out of 1171 processed
# VIIRS file 95 out of 1171 processed
# VIIRS file 96 out of 1171 processed
# VIIRS file 97 out of 1171 processed
# VIIRS file 98 out of 1171 processed
# VIIRS file 99 out of 1171 processed
# VIIRS file 100 out of 1171 processed
# VIIRS file 101 out of 1171 processed
# VIIRS file 102 out of 1171 processed
# VIIRS file 103 out of 1171 processed
# VIIRS file 104 out of 1171 processed
# VIIRS file 105 out of 1171 processed
# VIIRS file 106 out of 1171 processed
# VIIRS file 107 out of 1171 processed
# VIIRS file 108 out of 1171 processed
# VIIRS file 109 out of 1171 processed
# VIIRS file 110 out of 1171 processed
# VIIRS file 111 out of 1171 processed
# VIIRS file 112 out of 1171 processed
# VIIRS file 113 out of 1171 processed
# VIIRS file 114 out of 1171 processed
# VIIRS file 115 out of 1171 processed
# VIIRS file 116 out of 1171 processed
# VIIRS file 117 out of 1171 processed
# VIIRS file 118 out of 1171 processed
# VIIRS file 119 out of 1171 processed
# VIIRS file 120 out of 1171 processed
# VIIRS file 121 out of 1171 processed
# VIIRS file 122 out of 1171 processed
# VIIRS file 123 out of 1171 processed
# VIIRS file 124 out of 1171 processed
# VIIRS file 125 out of 1171 processed
# VIIRS file 126 out of 1171 processed
# VIIRS file 127 out of 1171 processed
# VIIRS file 128 out of 1171 processed
# VIIRS file 129 out of 1171 processed
# VIIRS file 130 out of 1171 processed
# VIIRS file 131 out of 1171 processed
# VIIRS file 132 out of 1171 processed
# VIIRS file 133 out of 1171 processed
# VIIRS file 134 out of 1171 processed
# VIIRS file 135 out of 1171 processed
# VIIRS file 136 out of 1171 processed
# VIIRS file 137 out of 1171 processed
# VIIRS file 138 out of 1171 processed
# VIIRS file 139 out of 1171 processed
# VIIRS file 140 out of 1171 processed
# VIIRS file 141 out of 1171 processed
# VIIRS file 142 out of 1171 processed
# VIIRS file 143 out of 1171 processed
# VIIRS file 144 out of 1171 processed
# VIIRS file 145 out of 1171 processed
# VIIRS file 146 out of 1171 processed
# VIIRS file 147 out of 1171 processed
# VIIRS file 148 out of 1171 processed
# VIIRS file 149 out of 1171 processed
# VIIRS file 150 out of 1171 processed
# VIIRS file 151 out of 1171 processed
# VIIRS file 152 out of 1171 processed
# VIIRS file 153 out of 1171 processed
# VIIRS file 154 out of 1171 processed
# VIIRS file 155 out of 1171 processed
# VIIRS file 156 out of 1171 processed
# VIIRS file 157 out of 1171 processed
# VIIRS file 158 out of 1171 processed
# VIIRS file 159 out of 1171 processed
# VIIRS file 160 out of 1171 processed
# VIIRS file 161 out of 1171 processed
# VIIRS file 162 out of 1171 processed
# VIIRS file 163 out of 1171 processed
# VIIRS file 164 out of 1171 processed
# VIIRS file 165 out of 1171 processed
# VIIRS file 166 out of 1171 processed
# VIIRS file 167 out of 1171 processed
# VIIRS file 168 out of 1171 processed
# VIIRS file 169 out of 1171 processed
# VIIRS file 170 out of 1171 processed
# VIIRS file 171 out of 1171 processed
# VIIRS file 172 out of 1171 processed
# VIIRS file 173 out of 1171 processed
# VIIRS file 174 out of 1171 processed
# VIIRS file 175 out of 1171 processed
# VIIRS file 176 out of 1171 processed
# VIIRS file 177 out of 1171 processed
# VIIRS file 178 out of 1171 processed
# VIIRS file 179 out of 1171 processed
# VIIRS file 180 out of 1171 processed
# VIIRS file 181 out of 1171 processed
# VIIRS file 182 out of 1171 processed
# VIIRS file 183 out of 1171 processed
# VIIRS file 184 out of 1171 processed
# VIIRS file 185 out of 1171 processed
# VIIRS file 186 out of 1171 processed
# VIIRS file 187 out of 1171 processed
# VIIRS file 188 out of 1171 processed
# VIIRS file 189 out of 1171 processed
# VIIRS file 190 out of 1171 processed
# VIIRS file 191 out of 1171 processed
# VIIRS file 192 out of 1171 processed
# VIIRS file 193 out of 1171 processed
# VIIRS file 194 out of 1171 processed
# VIIRS file 195 out of 1171 processed
# VIIRS file 196 out of 1171 processed
# VIIRS file 197 out of 1171 processed
# VIIRS file 198 out of 1171 processed
# VIIRS file 199 out of 1171 processed
# VIIRS file 200 out of 1171 processed
# VIIRS file 201 out of 1171 processed
# VIIRS file 202 out of 1171 processed
# VIIRS file 203 out of 1171 processed
# VIIRS file 204 out of 1171 processed
# VIIRS file 205 out of 1171 processed
# VIIRS file 206 out of 1171 processed
# VIIRS file 207 out of 1171 processed
# VIIRS file 208 out of 1171 processed
# VIIRS file 209 out of 1171 processed
# VIIRS file 210 out of 1171 processed
# VIIRS file 211 out of 1171 processed
# VIIRS file 212 out of 1171 processed
# VIIRS file 213 out of 1171 processed
# VIIRS file 214 out of 1171 processed
# VIIRS file 215 out of 1171 processed
# VIIRS file 216 out of 1171 processed
# VIIRS file 217 out of 1171 processed
# VIIRS file 218 out of 1171 processed
# VIIRS file 219 out of 1171 processed
# VIIRS file 220 out of 1171 processed
# VIIRS file 221 out of 1171 processed
# VIIRS file 222 out of 1171 processed
# VIIRS file 223 out of 1171 processed
# VIIRS file 224 out of 1171 processed
# VIIRS file 225 out of 1171 processed
# VIIRS file 226 out of 1171 processed
# VIIRS file 227 out of 1171 processed
# VIIRS file 228 out of 1171 processed
# VIIRS file 229 out of 1171 processed
# VIIRS file 230 out of 1171 processed
# VIIRS file 231 out of 1171 processed
# VIIRS file 232 out of 1171 processed
# VIIRS file 233 out of 1171 processed
# VIIRS file 234 out of 1171 processed
# VIIRS file 235 out of 1171 processed
# VIIRS file 236 out of 1171 processed
# VIIRS file 237 out of 1171 processed
# VIIRS file 238 out of 1171 processed
# VIIRS file 239 out of 1171 processed
# VIIRS file 240 out of 1171 processed
# VIIRS file 241 out of 1171 processed
# VIIRS file 242 out of 1171 processed
# VIIRS file 243 out of 1171 processed
# VIIRS file 244 out of 1171 processed
# VIIRS file 245 out of 1171 processed
# VIIRS file 246 out of 1171 processed
# VIIRS file 247 out of 1171 processed
# VIIRS file 248 out of 1171 processed
# VIIRS file 249 out of 1171 processed
# VIIRS file 250 out of 1171 processed
# VIIRS file 251 out of 1171 processed
# VIIRS file 252 out of 1171 processed
# VIIRS file 253 out of 1171 processed
# VIIRS file 254 out of 1171 processed
# VIIRS file 255 out of 1171 processed
# VIIRS file 256 out of 1171 processed
# VIIRS file 257 out of 1171 processed
# VIIRS file 258 out of 1171 processed
# VIIRS file 259 out of 1171 processed
# VIIRS file 260 out of 1171 processed
# VIIRS file 261 out of 1171 processed
# VIIRS file 262 out of 1171 processed
# VIIRS file 263 out of 1171 processed
# VIIRS file 264 out of 1171 processed
# VIIRS file 265 out of 1171 processed
# VIIRS file 266 out of 1171 processed
# VIIRS file 267 out of 1171 processed
# VIIRS file 268 out of 1171 processed
# VIIRS file 269 out of 1171 processed
# VIIRS file 270 out of 1171 processed
# VIIRS file 271 out of 1171 processed
# VIIRS file 272 out of 1171 processed
# VIIRS file 273 out of 1171 processed
# VIIRS file 274 out of 1171 processed
# VIIRS file 275 out of 1171 processed
# VIIRS file 276 out of 1171 processed
# VIIRS file 277 out of 1171 processed
# VIIRS file 278 out of 1171 processed
# VIIRS file 279 out of 1171 processed
# VIIRS file 280 out of 1171 processed
# VIIRS file 281 out of 1171 processed
# VIIRS file 282 out of 1171 processed
# VIIRS file 283 out of 1171 processed
# VIIRS file 284 out of 1171 processed
# VIIRS file 285 out of 1171 processed
# VIIRS file 286 out of 1171 processed
# VIIRS file 287 out of 1171 processed
# VIIRS file 288 out of 1171 processed
# VIIRS file 289 out of 1171 processed
# VIIRS file 290 out of 1171 processed
# VIIRS file 291 out of 1171 processed
# VIIRS file 292 out of 1171 processed
# VIIRS file 293 out of 1171 processed
# VIIRS file 294 out of 1171 processed
# VIIRS file 295 out of 1171 processed
# VIIRS file 296 out of 1171 processed
# VIIRS file 297 out of 1171 processed
# VIIRS file 298 out of 1171 processed
# VIIRS file 299 out of 1171 processed
# VIIRS file 300 out of 1171 processed
# VIIRS file 301 out of 1171 processed
# VIIRS file 302 out of 1171 processed
# VIIRS file 303 out of 1171 processed
# VIIRS file 304 out of 1171 processed
# VIIRS file 305 out of 1171 processed
# VIIRS file 306 out of 1171 processed
# VIIRS file 307 out of 1171 processed
# VIIRS file 308 out of 1171 processed
# VIIRS file 309 out of 1171 processed
# VIIRS file 310 out of 1171 processed
# VIIRS file 311 out of 1171 processed
# VIIRS file 312 out of 1171 processed
# VIIRS file 313 out of 1171 processed
# VIIRS file 314 out of 1171 processed
# VIIRS file 315 out of 1171 processed
# VIIRS file 316 out of 1171 processed
# VIIRS file 317 out of 1171 processed
# VIIRS file 318 out of 1171 processed
# VIIRS file 319 out of 1171 processed
# VIIRS file 320 out of 1171 processed
# VIIRS file 321 out of 1171 processed
# VIIRS file 322 out of 1171 processed
# VIIRS file 323 out of 1171 processed
# VIIRS file 324 out of 1171 processed
# VIIRS file 325 out of 1171 processed
# VIIRS file 326 out of 1171 processed
# VIIRS file 327 out of 1171 processed
# VIIRS file 328 out of 1171 processed
# VIIRS file 329 out of 1171 processed
# VIIRS file 330 out of 1171 processed
# VIIRS file 331 out of 1171 processed
# VIIRS file 332 out of 1171 processed
# VIIRS file 333 out of 1171 processed
# VIIRS file 334 out of 1171 processed
# VIIRS file 335 out of 1171 processed
# VIIRS file 336 out of 1171 processed
# VIIRS file 337 out of 1171 processed
# VIIRS file 338 out of 1171 processed
# VIIRS file 339 out of 1171 processed
# VIIRS file 340 out of 1171 processed
# VIIRS file 341 out of 1171 processed
# VIIRS file 342 out of 1171 processed
# VIIRS file 343 out of 1171 processed
# VIIRS file 344 out of 1171 processed
# VIIRS file 345 out of 1171 processed
# VIIRS file 346 out of 1171 processed
# VIIRS file 347 out of 1171 processed
# VIIRS file 348 out of 1171 processed
# VIIRS file 349 out of 1171 processed
# VIIRS file 350 out of 1171 processed
# VIIRS file 351 out of 1171 processed
# VIIRS file 352 out of 1171 processed
# VIIRS file 353 out of 1171 processed
# VIIRS file 354 out of 1171 processed
# VIIRS file 355 out of 1171 processed
# VIIRS file 356 out of 1171 processed
# VIIRS file 357 out of 1171 processed
# VIIRS file 358 out of 1171 processed
# VIIRS file 359 out of 1171 processed
# VIIRS file 360 out of 1171 processed
# VIIRS file 361 out of 1171 processed
# VIIRS file 362 out of 1171 processed
# VIIRS file 363 out of 1171 processed
# VIIRS file 364 out of 1171 processed
# VIIRS file 365 out of 1171 processed
# VIIRS file 366 out of 1171 processed
# VIIRS file 367 out of 1171 processed
# VIIRS file 368 out of 1171 processed
# VIIRS file 369 out of 1171 processed
# VIIRS file 370 out of 1171 processed
# VIIRS file 371 out of 1171 processed
# VIIRS file 372 out of 1171 processed
# VIIRS file 373 out of 1171 processed
# VIIRS file 374 out of 1171 processed
# VIIRS file 375 out of 1171 processed
# VIIRS file 376 out of 1171 processed
# VIIRS file 377 out of 1171 processed
# VIIRS file 378 out of 1171 processed
# VIIRS file 379 out of 1171 processed
# VIIRS file 380 out of 1171 processed
# VIIRS file 381 out of 1171 processed
# VIIRS file 382 out of 1171 processed
# VIIRS file 383 out of 1171 processed
# VIIRS file 384 out of 1171 processed
# VIIRS file 385 out of 1171 processed
# VIIRS file 386 out of 1171 processed
# VIIRS file 387 out of 1171 processed
# VIIRS file 388 out of 1171 processed
# VIIRS file 389 out of 1171 processed
# VIIRS file 390 out of 1171 processed
# VIIRS file 391 out of 1171 processed
# VIIRS file 392 out of 1171 processed
# VIIRS file 393 out of 1171 processed
# VIIRS file 394 out of 1171 processed
# VIIRS file 395 out of 1171 processed
# VIIRS file 396 out of 1171 processed
# VIIRS file 397 out of 1171 processed
# VIIRS file 398 out of 1171 processed
# VIIRS file 399 out of 1171 processed
# VIIRS file 400 out of 1171 processed
# VIIRS file 401 out of 1171 processed
# VIIRS file 402 out of 1171 processed
# VIIRS file 403 out of 1171 processed
# VIIRS file 404 out of 1171 processed
# VIIRS file 405 out of 1171 processed
# VIIRS file 406 out of 1171 processed
# VIIRS file 407 out of 1171 processed
# VIIRS file 408 out of 1171 processed
# VIIRS file 409 out of 1171 processed
# VIIRS file 410 out of 1171 processed
# VIIRS file 411 out of 1171 processed
# VIIRS file 412 out of 1171 processed
# VIIRS file 413 out of 1171 processed
# VIIRS file 414 out of 1171 processed
# VIIRS file 415 out of 1171 processed
# VIIRS file 416 out of 1171 processed
# VIIRS file 417 out of 1171 processed
# VIIRS file 418 out of 1171 processed
# VIIRS file 419 out of 1171 processed
# VIIRS file 420 out of 1171 processed
# VIIRS file 421 out of 1171 processed
# VIIRS file 422 out of 1171 processed
# VIIRS file 423 out of 1171 processed
# VIIRS file 424 out of 1171 processed
# VIIRS file 425 out of 1171 processed
# VIIRS file 426 out of 1171 processed
# VIIRS file 427 out of 1171 processed
# VIIRS file 428 out of 1171 processed
# VIIRS file 429 out of 1171 processed
# VIIRS file 430 out of 1171 processed
# VIIRS file 431 out of 1171 processed
# VIIRS file 432 out of 1171 processed
# VIIRS file 433 out of 1171 processed
# VIIRS file 434 out of 1171 processed
# VIIRS file 435 out of 1171 processed
# VIIRS file 436 out of 1171 processed
# VIIRS file 437 out of 1171 processed
# VIIRS file 438 out of 1171 processed
# VIIRS file 439 out of 1171 processed
# VIIRS file 440 out of 1171 processed
# VIIRS file 441 out of 1171 processed
# VIIRS file 442 out of 1171 processed
# VIIRS file 443 out of 1171 processed
# VIIRS file 444 out of 1171 processed
# VIIRS file 445 out of 1171 processed
# VIIRS file 446 out of 1171 processed
# VIIRS file 447 out of 1171 processed
# VIIRS file 448 out of 1171 processed
# VIIRS file 449 out of 1171 processed
# VIIRS file 450 out of 1171 processed
# VIIRS file 451 out of 1171 processed
# VIIRS file 452 out of 1171 processed
# VIIRS file 453 out of 1171 processed
# VIIRS file 454 out of 1171 processed
# VIIRS file 455 out of 1171 processed
# VIIRS file 456 out of 1171 processed
# VIIRS file 457 out of 1171 processed
# VIIRS file 458 out of 1171 processed
# VIIRS file 459 out of 1171 processed
# VIIRS file 460 out of 1171 processed
# VIIRS file 461 out of 1171 processed
# VIIRS file 462 out of 1171 processed
# VIIRS file 463 out of 1171 processed
# VIIRS file 464 out of 1171 processed
# VIIRS file 465 out of 1171 processed
# VIIRS file 466 out of 1171 processed
# VIIRS file 467 out of 1171 processed
# VIIRS file 468 out of 1171 processed
# VIIRS file 469 out of 1171 processed
# VIIRS file 470 out of 1171 processed
# VIIRS file 471 out of 1171 processed
# VIIRS file 472 out of 1171 processed
# VIIRS file 473 out of 1171 processed
# VIIRS file 474 out of 1171 processed
# VIIRS file 475 out of 1171 processed
# VIIRS file 476 out of 1171 processed
# VIIRS file 477 out of 1171 processed
# VIIRS file 478 out of 1171 processed
# VIIRS file 479 out of 1171 processed
# VIIRS file 480 out of 1171 processed
# VIIRS file 481 out of 1171 processed
# VIIRS file 482 out of 1171 processed
# VIIRS file 483 out of 1171 processed
# VIIRS file 484 out of 1171 processed
# VIIRS file 485 out of 1171 processed
# VIIRS file 486 out of 1171 processed
# VIIRS file 487 out of 1171 processed
# VIIRS file 488 out of 1171 processed
# VIIRS file 489 out of 1171 processed
# VIIRS file 490 out of 1171 processed
# VIIRS file 491 out of 1171 processed
# VIIRS file 492 out of 1171 processed
# VIIRS file 493 out of 1171 processed
# VIIRS file 494 out of 1171 processed
# VIIRS file 495 out of 1171 processed
# VIIRS file 496 out of 1171 processed
# VIIRS file 497 out of 1171 processed
# VIIRS file 498 out of 1171 processed
# VIIRS file 499 out of 1171 processed
# VIIRS file 500 out of 1171 processed
# VIIRS file 501 out of 1171 processed
# VIIRS file 502 out of 1171 processed
# VIIRS file 503 out of 1171 processed
# VIIRS file 504 out of 1171 processed
# VIIRS file 505 out of 1171 processed
# VIIRS file 506 out of 1171 processed
# VIIRS file 507 out of 1171 processed
# VIIRS file 508 out of 1171 processed
# VIIRS file 509 out of 1171 processed
# VIIRS file 510 out of 1171 processed
# VIIRS file 511 out of 1171 processed
# VIIRS file 512 out of 1171 processed
# VIIRS file 513 out of 1171 processed
# VIIRS file 514 out of 1171 processed
# VIIRS file 515 out of 1171 processed
# VIIRS file 516 out of 1171 processed
# VIIRS file 517 out of 1171 processed
# VIIRS file 518 out of 1171 processed
# VIIRS file 519 out of 1171 processed
# VIIRS file 520 out of 1171 processed
# VIIRS file 521 out of 1171 processed
# VIIRS file 522 out of 1171 processed
# VIIRS file 523 out of 1171 processed
# VIIRS file 524 out of 1171 processed
# VIIRS file 525 out of 1171 processed
# VIIRS file 526 out of 1171 processed
# VIIRS file 527 out of 1171 processed
# VIIRS file 528 out of 1171 processed
# VIIRS file 529 out of 1171 processed
# VIIRS file 530 out of 1171 processed
# VIIRS file 531 out of 1171 processed
# VIIRS file 532 out of 1171 processed
# VIIRS file 533 out of 1171 processed
# VIIRS file 534 out of 1171 processed
# VIIRS file 535 out of 1171 processed
# VIIRS file 536 out of 1171 processed
# VIIRS file 537 out of 1171 processed
# VIIRS file 538 out of 1171 processed
# VIIRS file 539 out of 1171 processed
# VIIRS file 540 out of 1171 processed
# VIIRS file 541 out of 1171 processed
# VIIRS file 542 out of 1171 processed
# VIIRS file 543 out of 1171 processed
# VIIRS file 544 out of 1171 processed
# VIIRS file 545 out of 1171 processed
# VIIRS file 546 out of 1171 processed
# VIIRS file 547 out of 1171 processed
# VIIRS file 548 out of 1171 processed
# VIIRS file 549 out of 1171 processed
# VIIRS file 550 out of 1171 processed
# VIIRS file 551 out of 1171 processed
# VIIRS file 552 out of 1171 processed
# VIIRS file 553 out of 1171 processed
# VIIRS file 554 out of 1171 processed
# VIIRS file 555 out of 1171 processed
# VIIRS file 556 out of 1171 processed
# VIIRS file 557 out of 1171 processed
# VIIRS file 558 out of 1171 processed
# VIIRS file 559 out of 1171 processed
# VIIRS file 560 out of 1171 processed
# VIIRS file 561 out of 1171 processed
# VIIRS file 562 out of 1171 processed
# VIIRS file 563 out of 1171 processed
# VIIRS file 564 out of 1171 processed
# VIIRS file 565 out of 1171 processed
# VIIRS file 566 out of 1171 processed
# VIIRS file 567 out of 1171 processed
# VIIRS file 568 out of 1171 processed
# VIIRS file 569 out of 1171 processed
# VIIRS file 570 out of 1171 processed
# VIIRS file 571 out of 1171 processed
# VIIRS file 572 out of 1171 processed
# VIIRS file 573 out of 1171 processed
# VIIRS file 574 out of 1171 processed
# VIIRS file 575 out of 1171 processed
# VIIRS file 576 out of 1171 processed
# VIIRS file 577 out of 1171 processed
# VIIRS file 578 out of 1171 processed
# VIIRS file 579 out of 1171 processed
# VIIRS file 580 out of 1171 processed
# VIIRS file 581 out of 1171 processed
# VIIRS file 582 out of 1171 processed
# VIIRS file 583 out of 1171 processed
# VIIRS file 584 out of 1171 processed
# VIIRS file 585 out of 1171 processed
# VIIRS file 586 out of 1171 processed
# VIIRS file 587 out of 1171 processed
# VIIRS file 588 out of 1171 processed
# VIIRS file 589 out of 1171 processed
# VIIRS file 590 out of 1171 processed
# VIIRS file 591 out of 1171 processed
# VIIRS file 592 out of 1171 processed
# VIIRS file 593 out of 1171 processed
# VIIRS file 594 out of 1171 processed
# VIIRS file 595 out of 1171 processed
# VIIRS file 596 out of 1171 processed
# VIIRS file 597 out of 1171 processed
# VIIRS file 598 out of 1171 processed
# VIIRS file 599 out of 1171 processed
# VIIRS file 600 out of 1171 processed
# VIIRS file 601 out of 1171 processed
# VIIRS file 602 out of 1171 processed
# VIIRS file 603 out of 1171 processed
# VIIRS file 604 out of 1171 processed
# VIIRS file 605 out of 1171 processed
# VIIRS file 606 out of 1171 processed
# VIIRS file 607 out of 1171 processed
# VIIRS file 608 out of 1171 processed
# VIIRS file 609 out of 1171 processed
# VIIRS file 610 out of 1171 processed
# VIIRS file 611 out of 1171 processed
# VIIRS file 612 out of 1171 processed
# VIIRS file 613 out of 1171 processed
# VIIRS file 614 out of 1171 processed
# VIIRS file 615 out of 1171 processed
# VIIRS file 616 out of 1171 processed
# VIIRS file 617 out of 1171 processed
# VIIRS file 618 out of 1171 processed
# VIIRS file 619 out of 1171 processed
# VIIRS file 620 out of 1171 processed
# VIIRS file 621 out of 1171 processed
# VIIRS file 622 out of 1171 processed
# VIIRS file 623 out of 1171 processed
# VIIRS file 624 out of 1171 processed
# VIIRS file 625 out of 1171 processed
# VIIRS file 626 out of 1171 processed
# VIIRS file 627 out of 1171 processed
# VIIRS file 628 out of 1171 processed
# VIIRS file 629 out of 1171 processed
# VIIRS file 630 out of 1171 processed
# VIIRS file 631 out of 1171 processed
# VIIRS file 632 out of 1171 processed
# VIIRS file 633 out of 1171 processed
# VIIRS file 634 out of 1171 processed
# VIIRS file 635 out of 1171 processed
# VIIRS file 636 out of 1171 processed
# VIIRS file 637 out of 1171 processed
# VIIRS file 638 out of 1171 processed
# VIIRS file 639 out of 1171 processed
# VIIRS file 640 out of 1171 processed
# VIIRS file 641 out of 1171 processed
# VIIRS file 642 out of 1171 processed
# VIIRS file 643 out of 1171 processed
# VIIRS file 644 out of 1171 processed
# VIIRS file 645 out of 1171 processed
# VIIRS file 646 out of 1171 processed
# VIIRS file 647 out of 1171 processed
# VIIRS file 648 out of 1171 processed
# VIIRS file 649 out of 1171 processed
# VIIRS file 650 out of 1171 processed
# VIIRS file 651 out of 1171 processed
# VIIRS file 652 out of 1171 processed
# VIIRS file 653 out of 1171 processed
# VIIRS file 654 out of 1171 processed
# VIIRS file 655 out of 1171 processed
# VIIRS file 656 out of 1171 processed
# VIIRS file 657 out of 1171 processed
# VIIRS file 658 out of 1171 processed
# VIIRS file 659 out of 1171 processed
# VIIRS file 660 out of 1171 processed
# VIIRS file 661 out of 1171 processed
# VIIRS file 662 out of 1171 processed
# VIIRS file 663 out of 1171 processed
# VIIRS file 664 out of 1171 processed
# VIIRS file 665 out of 1171 processed
# VIIRS file 666 out of 1171 processed
# VIIRS file 667 out of 1171 processed
# VIIRS file 668 out of 1171 processed
# VIIRS file 669 out of 1171 processed
# VIIRS file 670 out of 1171 processed
# VIIRS file 671 out of 1171 processed
# VIIRS file 672 out of 1171 processed
# VIIRS file 673 out of 1171 processed
# VIIRS file 674 out of 1171 processed
# VIIRS file 675 out of 1171 processed
# VIIRS file 676 out of 1171 processed
# VIIRS file 677 out of 1171 processed
# VIIRS file 678 out of 1171 processed
# VIIRS file 679 out of 1171 processed
# VIIRS file 680 out of 1171 processed
# VIIRS file 681 out of 1171 processed
# VIIRS file 682 out of 1171 processed
# VIIRS file 683 out of 1171 processed
# VIIRS file 684 out of 1171 processed
# VIIRS file 685 out of 1171 processed
# VIIRS file 686 out of 1171 processed
# VIIRS file 687 out of 1171 processed
# VIIRS file 688 out of 1171 processed
# VIIRS file 689 out of 1171 processed
# VIIRS file 690 out of 1171 processed
# VIIRS file 691 out of 1171 processed
# VIIRS file 692 out of 1171 processed
# VIIRS file 693 out of 1171 processed
# VIIRS file 694 out of 1171 processed
# VIIRS file 695 out of 1171 processed
# VIIRS file 696 out of 1171 processed
# VIIRS file 697 out of 1171 processed
# VIIRS file 698 out of 1171 processed
# VIIRS file 699 out of 1171 processed
# VIIRS file 700 out of 1171 processed
# VIIRS file 701 out of 1171 processed
# VIIRS file 702 out of 1171 processed
# VIIRS file 703 out of 1171 processed
# VIIRS file 704 out of 1171 processed
# VIIRS file 705 out of 1171 processed
# VIIRS file 706 out of 1171 processed
# VIIRS file 707 out of 1171 processed
# VIIRS file 708 out of 1171 processed
# VIIRS file 709 out of 1171 processed
# VIIRS file 710 out of 1171 processed
# VIIRS file 711 out of 1171 processed
# VIIRS file 712 out of 1171 processed
# VIIRS file 713 out of 1171 processed
# VIIRS file 714 out of 1171 processed
# VIIRS file 715 out of 1171 processed
# VIIRS file 716 out of 1171 processed
# VIIRS file 717 out of 1171 processed
# VIIRS file 718 out of 1171 processed
# VIIRS file 719 out of 1171 processed
# VIIRS file 720 out of 1171 processed
# VIIRS file 721 out of 1171 processed
# VIIRS file 722 out of 1171 processed
# VIIRS file 723 out of 1171 processed
# VIIRS file 724 out of 1171 processed
# VIIRS file 725 out of 1171 processed
# VIIRS file 726 out of 1171 processed
# VIIRS file 727 out of 1171 processed
# VIIRS file 728 out of 1171 processed
# VIIRS file 729 out of 1171 processed
# VIIRS file 730 out of 1171 processed
# VIIRS file 731 out of 1171 processed
# VIIRS file 732 out of 1171 processed
# VIIRS file 733 out of 1171 processed
# VIIRS file 734 out of 1171 processed
# VIIRS file 735 out of 1171 processed
# VIIRS file 736 out of 1171 processed
# VIIRS file 737 out of 1171 processed
# VIIRS file 738 out of 1171 processed
# VIIRS file 739 out of 1171 processed
# VIIRS file 740 out of 1171 processed
# VIIRS file 741 out of 1171 processed
# VIIRS file 742 out of 1171 processed
# VIIRS file 743 out of 1171 processed
# VIIRS file 744 out of 1171 processed
# VIIRS file 745 out of 1171 processed
# VIIRS file 746 out of 1171 processed
# VIIRS file 747 out of 1171 processed
# VIIRS file 748 out of 1171 processed
# VIIRS file 749 out of 1171 processed
# VIIRS file 750 out of 1171 processed
# VIIRS file 751 out of 1171 processed
# VIIRS file 752 out of 1171 processed
# VIIRS file 753 out of 1171 processed
# VIIRS file 754 out of 1171 processed
# VIIRS file 755 out of 1171 processed
# VIIRS file 756 out of 1171 processed
# VIIRS file 757 out of 1171 processed
# VIIRS file 758 out of 1171 processed
# VIIRS file 759 out of 1171 processed
# VIIRS file 760 out of 1171 processed
# VIIRS file 761 out of 1171 processed
# VIIRS file 762 out of 1171 processed
# VIIRS file 763 out of 1171 processed
# VIIRS file 764 out of 1171 processed
# VIIRS file 765 out of 1171 processed
# VIIRS file 766 out of 1171 processed
# VIIRS file 767 out of 1171 processed
# VIIRS file 768 out of 1171 processed
# VIIRS file 769 out of 1171 processed
# VIIRS file 770 out of 1171 processed
# VIIRS file 771 out of 1171 processed
# VIIRS file 772 out of 1171 processed
# VIIRS file 773 out of 1171 processed
# VIIRS file 774 out of 1171 processed
# VIIRS file 775 out of 1171 processed
# VIIRS file 776 out of 1171 processed
# VIIRS file 777 out of 1171 processed
# VIIRS file 778 out of 1171 processed
# VIIRS file 779 out of 1171 processed
# VIIRS file 780 out of 1171 processed
# VIIRS file 781 out of 1171 processed
# VIIRS file 782 out of 1171 processed
# VIIRS file 783 out of 1171 processed
# VIIRS file 784 out of 1171 processed
# VIIRS file 785 out of 1171 processed
# VIIRS file 786 out of 1171 processed
# VIIRS file 787 out of 1171 processed
# VIIRS file 788 out of 1171 processed
# VIIRS file 789 out of 1171 processed
# VIIRS file 790 out of 1171 processed
# VIIRS file 791 out of 1171 processed
# VIIRS file 792 out of 1171 processed
# VIIRS file 793 out of 1171 processed
# VIIRS file 794 out of 1171 processed
# VIIRS file 795 out of 1171 processed
# VIIRS file 796 out of 1171 processed
# VIIRS file 797 out of 1171 processed
# VIIRS file 798 out of 1171 processed
# VIIRS file 799 out of 1171 processed
# VIIRS file 800 out of 1171 processed
# VIIRS file 801 out of 1171 processed
# VIIRS file 802 out of 1171 processed
# VIIRS file 803 out of 1171 processed
# VIIRS file 804 out of 1171 processed
# VIIRS file 805 out of 1171 processed
# VIIRS file 806 out of 1171 processed
# VIIRS file 807 out of 1171 processed
# VIIRS file 808 out of 1171 processed
# VIIRS file 809 out of 1171 processed
# VIIRS file 810 out of 1171 processed
# VIIRS file 811 out of 1171 processed
# VIIRS file 812 out of 1171 processed
# VIIRS file 813 out of 1171 processed
# VIIRS file 814 out of 1171 processed
# VIIRS file 815 out of 1171 processed
# VIIRS file 816 out of 1171 processed
# VIIRS file 817 out of 1171 processed
# VIIRS file 818 out of 1171 processed
# VIIRS file 819 out of 1171 processed
# VIIRS file 820 out of 1171 processed
# VIIRS file 821 out of 1171 processed
# VIIRS file 822 out of 1171 processed
# VIIRS file 823 out of 1171 processed
# VIIRS file 824 out of 1171 processed
# VIIRS file 825 out of 1171 processed
# VIIRS file 826 out of 1171 processed
# VIIRS file 827 out of 1171 processed
# VIIRS file 828 out of 1171 processed
# VIIRS file 829 out of 1171 processed
# VIIRS file 830 out of 1171 processed
# VIIRS file 831 out of 1171 processed
# VIIRS file 832 out of 1171 processed
# VIIRS file 833 out of 1171 processed
# VIIRS file 834 out of 1171 processed
# VIIRS file 835 out of 1171 processed
# VIIRS file 836 out of 1171 processed
# VIIRS file 837 out of 1171 processed
# VIIRS file 838 out of 1171 processed
# VIIRS file 839 out of 1171 processed
# VIIRS file 840 out of 1171 processed
# VIIRS file 841 out of 1171 processed
# VIIRS file 842 out of 1171 processed
# VIIRS file 843 out of 1171 processed
# VIIRS file 844 out of 1171 processed
# VIIRS file 845 out of 1171 processed
# VIIRS file 846 out of 1171 processed
# VIIRS file 847 out of 1171 processed
# VIIRS file 848 out of 1171 processed
# VIIRS file 849 out of 1171 processed
# VIIRS file 850 out of 1171 processed
# VIIRS file 851 out of 1171 processed
# VIIRS file 852 out of 1171 processed
# VIIRS file 853 out of 1171 processed
# VIIRS file 854 out of 1171 processed
# VIIRS file 855 out of 1171 processed
# VIIRS file 856 out of 1171 processed
# VIIRS file 857 out of 1171 processed
# VIIRS file 858 out of 1171 processed
# VIIRS file 859 out of 1171 processed
# VIIRS file 860 out of 1171 processed
# VIIRS file 861 out of 1171 processed
# VIIRS file 862 out of 1171 processed
# VIIRS file 863 out of 1171 processed
# VIIRS file 864 out of 1171 processed
# VIIRS file 865 out of 1171 processed
# VIIRS file 866 out of 1171 processed
# VIIRS file 867 out of 1171 processed
# VIIRS file 868 out of 1171 processed
# VIIRS file 869 out of 1171 processed
# VIIRS file 870 out of 1171 processed
# VIIRS file 871 out of 1171 processed
# VIIRS file 872 out of 1171 processed
# VIIRS file 873 out of 1171 processed
# VIIRS file 874 out of 1171 processed
# VIIRS file 875 out of 1171 processed
# VIIRS file 876 out of 1171 processed
# VIIRS file 877 out of 1171 processed
# VIIRS file 878 out of 1171 processed
# VIIRS file 879 out of 1171 processed
# VIIRS file 880 out of 1171 processed
# VIIRS file 881 out of 1171 processed
# VIIRS file 882 out of 1171 processed
# VIIRS file 883 out of 1171 processed
# VIIRS file 884 out of 1171 processed
# VIIRS file 885 out of 1171 processed
# VIIRS file 886 out of 1171 processed
# VIIRS file 887 out of 1171 processed
# VIIRS file 888 out of 1171 processed
# VIIRS file 889 out of 1171 processed
# VIIRS file 890 out of 1171 processed
# VIIRS file 891 out of 1171 processed
# VIIRS file 892 out of 1171 processed
# VIIRS file 893 out of 1171 processed
# VIIRS file 894 out of 1171 processed
# VIIRS file 895 out of 1171 processed
# VIIRS file 896 out of 1171 processed
# VIIRS file 897 out of 1171 processed
# VIIRS file 898 out of 1171 processed
# VIIRS file 899 out of 1171 processed
# VIIRS file 900 out of 1171 processed
# VIIRS file 901 out of 1171 processed
# VIIRS file 902 out of 1171 processed
# VIIRS file 903 out of 1171 processed
# VIIRS file 904 out of 1171 processed
# VIIRS file 905 out of 1171 processed
# VIIRS file 906 out of 1171 processed
# VIIRS file 907 out of 1171 processed
# VIIRS file 908 out of 1171 processed
# VIIRS file 909 out of 1171 processed
# VIIRS file 910 out of 1171 processed
# VIIRS file 911 out of 1171 processed
# VIIRS file 912 out of 1171 processed
# VIIRS file 913 out of 1171 processed
# VIIRS file 914 out of 1171 processed
# VIIRS file 915 out of 1171 processed
# VIIRS file 916 out of 1171 processed
# VIIRS file 917 out of 1171 processed
# VIIRS file 918 out of 1171 processed
# VIIRS file 919 out of 1171 processed
# VIIRS file 920 out of 1171 processed
# VIIRS file 921 out of 1171 processed
# VIIRS file 922 out of 1171 processed
# VIIRS file 923 out of 1171 processed
# VIIRS file 924 out of 1171 processed
# VIIRS file 925 out of 1171 processed
# VIIRS file 926 out of 1171 processed
# VIIRS file 927 out of 1171 processed
# VIIRS file 928 out of 1171 processed
# VIIRS file 929 out of 1171 processed
# VIIRS file 930 out of 1171 processed
# VIIRS file 931 out of 1171 processed
# VIIRS file 932 out of 1171 processed
# VIIRS file 933 out of 1171 processed
# VIIRS file 934 out of 1171 processed
# VIIRS file 935 out of 1171 processed
# VIIRS file 936 out of 1171 processed
# VIIRS file 937 out of 1171 processed
# VIIRS file 938 out of 1171 processed
# VIIRS file 939 out of 1171 processed
# VIIRS file 940 out of 1171 processed
# VIIRS file 941 out of 1171 processed
# VIIRS file 942 out of 1171 processed
# VIIRS file 943 out of 1171 processed
# VIIRS file 944 out of 1171 processed
# VIIRS file 945 out of 1171 processed
# VIIRS file 946 out of 1171 processed
# VIIRS file 947 out of 1171 processed
# VIIRS file 948 out of 1171 processed
# VIIRS file 949 out of 1171 processed
# VIIRS file 950 out of 1171 processed
# VIIRS file 951 out of 1171 processed
# VIIRS file 952 out of 1171 processed
# VIIRS file 953 out of 1171 processed
# VIIRS file 954 out of 1171 processed
# VIIRS file 955 out of 1171 processed
# VIIRS file 956 out of 1171 processed
# VIIRS file 957 out of 1171 processed
# VIIRS file 958 out of 1171 processed
# VIIRS file 959 out of 1171 processed
# VIIRS file 960 out of 1171 processed
# VIIRS file 961 out of 1171 processed
# VIIRS file 962 out of 1171 processed
# VIIRS file 963 out of 1171 processed
# VIIRS file 964 out of 1171 processed
# VIIRS file 965 out of 1171 processed
# VIIRS file 966 out of 1171 processed
# VIIRS file 967 out of 1171 processed
# VIIRS file 968 out of 1171 processed
# VIIRS file 969 out of 1171 processed
# VIIRS file 970 out of 1171 processed
# VIIRS file 971 out of 1171 processed
# VIIRS file 972 out of 1171 processed
# VIIRS file 973 out of 1171 processed
# VIIRS file 974 out of 1171 processed
# VIIRS file 975 out of 1171 processed
# VIIRS file 976 out of 1171 processed
# VIIRS file 977 out of 1171 processed
# VIIRS file 978 out of 1171 processed
# VIIRS file 979 out of 1171 processed
# VIIRS file 980 out of 1171 processed
# VIIRS file 981 out of 1171 processed
# VIIRS file 982 out of 1171 processed
# VIIRS file 983 out of 1171 processed
# VIIRS file 984 out of 1171 processed
# VIIRS file 985 out of 1171 processed
# VIIRS file 986 out of 1171 processed
# VIIRS file 987 out of 1171 processed
# VIIRS file 988 out of 1171 processed
# VIIRS file 989 out of 1171 processed
# VIIRS file 990 out of 1171 processed
# VIIRS file 991 out of 1171 processed
# VIIRS file 992 out of 1171 processed
# VIIRS file 993 out of 1171 processed
# VIIRS file 994 out of 1171 processed
# VIIRS file 995 out of 1171 processed
# VIIRS file 996 out of 1171 processed
# VIIRS file 997 out of 1171 processed
# VIIRS file 998 out of 1171 processed
# VIIRS file 999 out of 1171 processed
# VIIRS file 1000 out of 1171 processed
# VIIRS file 1001 out of 1171 processed
# VIIRS file 1002 out of 1171 processed
# VIIRS file 1003 out of 1171 processed
# VIIRS file 1004 out of 1171 processed
# VIIRS file 1005 out of 1171 processed
# VIIRS file 1006 out of 1171 processed
# VIIRS file 1007 out of 1171 processed
# VIIRS file 1008 out of 1171 processed
# VIIRS file 1009 out of 1171 processed
# VIIRS file 1010 out of 1171 processed
# VIIRS file 1011 out of 1171 processed
# VIIRS file 1012 out of 1171 processed
# VIIRS file 1013 out of 1171 processed
# VIIRS file 1014 out of 1171 processed
# VIIRS file 1015 out of 1171 processed
# VIIRS file 1016 out of 1171 processed
# VIIRS file 1017 out of 1171 processed
# VIIRS file 1018 out of 1171 processed
# VIIRS file 1019 out of 1171 processed
# VIIRS file 1020 out of 1171 processed
# VIIRS file 1021 out of 1171 processed
# VIIRS file 1022 out of 1171 processed
# VIIRS file 1023 out of 1171 processed
# VIIRS file 1024 out of 1171 processed
# VIIRS file 1025 out of 1171 processed
# VIIRS file 1026 out of 1171 processed
# VIIRS file 1027 out of 1171 processed
# VIIRS file 1028 out of 1171 processed
# VIIRS file 1029 out of 1171 processed
# VIIRS file 1030 out of 1171 processed
# VIIRS file 1031 out of 1171 processed
# VIIRS file 1032 out of 1171 processed
# VIIRS file 1033 out of 1171 processed
# VIIRS file 1034 out of 1171 processed
# VIIRS file 1035 out of 1171 processed
# VIIRS file 1036 out of 1171 processed
# VIIRS file 1037 out of 1171 processed
# VIIRS file 1038 out of 1171 processed
# VIIRS file 1039 out of 1171 processed
# VIIRS file 1040 out of 1171 processed
# VIIRS file 1041 out of 1171 processed
# VIIRS file 1042 out of 1171 processed
# VIIRS file 1043 out of 1171 processed
# VIIRS file 1044 out of 1171 processed
# VIIRS file 1045 out of 1171 processed
# VIIRS file 1046 out of 1171 processed
# VIIRS file 1047 out of 1171 processed
# VIIRS file 1048 out of 1171 processed
# VIIRS file 1049 out of 1171 processed
# VIIRS file 1050 out of 1171 processed
# VIIRS file 1051 out of 1171 processed
# VIIRS file 1052 out of 1171 processed
# VIIRS file 1053 out of 1171 processed
# VIIRS file 1054 out of 1171 processed
# VIIRS file 1055 out of 1171 processed
# VIIRS file 1056 out of 1171 processed
# VIIRS file 1057 out of 1171 processed
# VIIRS file 1058 out of 1171 processed
# VIIRS file 1059 out of 1171 processed
# VIIRS file 1060 out of 1171 processed
# VIIRS file 1061 out of 1171 processed
# VIIRS file 1062 out of 1171 processed
# VIIRS file 1063 out of 1171 processed
# VIIRS file 1064 out of 1171 processed
# VIIRS file 1065 out of 1171 processed
# VIIRS file 1066 out of 1171 processed
# VIIRS file 1067 out of 1171 processed
# VIIRS file 1068 out of 1171 processed
# VIIRS file 1069 out of 1171 processed
# VIIRS file 1070 out of 1171 processed
# VIIRS file 1071 out of 1171 processed
# VIIRS file 1072 out of 1171 processed
# VIIRS file 1073 out of 1171 processed
# VIIRS file 1074 out of 1171 processed
# VIIRS file 1075 out of 1171 processed
# VIIRS file 1076 out of 1171 processed
# VIIRS file 1077 out of 1171 processed
# VIIRS file 1078 out of 1171 processed
# VIIRS file 1079 out of 1171 processed
# VIIRS file 1080 out of 1171 processed
# VIIRS file 1081 out of 1171 processed
# VIIRS file 1082 out of 1171 processed
# VIIRS file 1083 out of 1171 processed
# VIIRS file 1084 out of 1171 processed
# VIIRS file 1085 out of 1171 processed
# VIIRS file 1086 out of 1171 processed
# VIIRS file 1087 out of 1171 processed
# VIIRS file 1088 out of 1171 processed
# VIIRS file 1089 out of 1171 processed
# VIIRS file 1090 out of 1171 processed
# VIIRS file 1091 out of 1171 processed
# VIIRS file 1092 out of 1171 processed
# VIIRS file 1093 out of 1171 processed
# VIIRS file 1094 out of 1171 processed
# VIIRS file 1095 out of 1171 processed
# VIIRS file 1096 out of 1171 processed
# VIIRS file 1097 out of 1171 processed
# VIIRS file 1098 out of 1171 processed
# VIIRS file 1099 out of 1171 processed
# VIIRS file 1100 out of 1171 processed
# VIIRS file 1101 out of 1171 processed
# VIIRS file 1102 out of 1171 processed
# VIIRS file 1103 out of 1171 processed
# VIIRS file 1104 out of 1171 processed
# VIIRS file 1105 out of 1171 processed
# VIIRS file 1106 out of 1171 processed
# VIIRS file 1107 out of 1171 processed
# VIIRS file 1108 out of 1171 processed
# VIIRS file 1109 out of 1171 processed
# VIIRS file 1110 out of 1171 processed
# VIIRS file 1111 out of 1171 processed
# VIIRS file 1112 out of 1171 processed
# VIIRS file 1113 out of 1171 processed
# VIIRS file 1114 out of 1171 processed
# VIIRS file 1115 out of 1171 processed
# VIIRS file 1116 out of 1171 processed
# VIIRS file 1117 out of 1171 processed
# VIIRS file 1118 out of 1171 processed
# VIIRS file 1119 out of 1171 processed
# VIIRS file 1120 out of 1171 processed
# VIIRS file 1121 out of 1171 processed
# VIIRS file 1122 out of 1171 processed
# VIIRS file 1123 out of 1171 processed
# VIIRS file 1124 out of 1171 processed
# VIIRS file 1125 out of 1171 processed
# VIIRS file 1126 out of 1171 processed
# VIIRS file 1127 out of 1171 processed
# VIIRS file 1128 out of 1171 processed
# VIIRS file 1129 out of 1171 processed
# VIIRS file 1130 out of 1171 processed
# VIIRS file 1131 out of 1171 processed
# VIIRS file 1132 out of 1171 processed
# VIIRS file 1133 out of 1171 processed
# VIIRS file 1134 out of 1171 processed
# VIIRS file 1135 out of 1171 processed
# VIIRS file 1136 out of 1171 processed
# VIIRS file 1137 out of 1171 processed
# VIIRS file 1138 out of 1171 processed
# VIIRS file 1139 out of 1171 processed
# VIIRS file 1140 out of 1171 processed
# VIIRS file 1141 out of 1171 processed
# VIIRS file 1142 out of 1171 processed
# VIIRS file 1143 out of 1171 processed
# VIIRS file 1144 out of 1171 processed
# VIIRS file 1145 out of 1171 processed
# VIIRS file 1146 out of 1171 processed
# VIIRS file 1147 out of 1171 processed
# VIIRS file 1148 out of 1171 processed
# VIIRS file 1149 out of 1171 processed
# VIIRS file 1150 out of 1171 processed
# VIIRS file 1151 out of 1171 processed
# VIIRS file 1152 out of 1171 processed
# VIIRS file 1153 out of 1171 processed
# VIIRS file 1154 out of 1171 processed
# VIIRS file 1155 out of 1171 processed
# VIIRS file 1156 out of 1171 processed
# VIIRS file 1157 out of 1171 processed
# VIIRS file 1158 out of 1171 processed
# VIIRS file 1159 out of 1171 processed
# VIIRS file 1160 out of 1171 processed
# VIIRS file 1161 out of 1171 processed
# VIIRS file 1162 out of 1171 processed
# VIIRS file 1163 out of 1171 processed
# VIIRS file 1164 out of 1171 processed
# VIIRS file 1165 out of 1171 processed
# VIIRS file 1166 out of 1171 processed
# VIIRS file 1167 out of 1171 processed
# VIIRS file 1168 out of 1171 processed
# VIIRS file 1169 out of 1171 processed
# VIIRS file 1170 out of 1171 processed
# VIIRS file 1171 out of 1171 processed

# %%
VIIRS_points_concat = pd.concat(VIIRS_points) ## concatenate the points
print(f"Total number of fire pixels: {len(VIIRS_points_concat)}") ## print the total number of fire pixels
VIIRS_points_concat[:5] ## show the first 5 rows
# Out:
# Total number of fire pixels: 227323
#     latitude   longitude                                    Fire_file  \
# 0  62.578159 -105.049248  VNP14IMG.A2022152.0824.001.2022155015212.nc
# 1  58.585060 -116.972847  VNP14IMG.A2022152.0824.001.2022155015212.nc
# 2  58.577908 -116.971733  VNP14IMG.A2022152.0824.001.2022155015212.nc
# 3  57.405655 -111.052505  VNP14IMG.A2022152.0824.001.2022155015212.nc
# 4  57.041893 -111.638710  VNP14IMG.A2022152.0824.001.2022155015212.nc
#
#   Unique_date Unique_time        DATE   TIME         DATE_TIME  \
# 0    A2022152        0824  2022-06-01  08:24  2022-06-01 08:24
# 1    A2022152        0824  2022-06-01  08:24  2022-06-01 08:24
# 2    A2022152        0824  2022-06-01  08:24  2022-06-01 08:24
# 3    A2022152        0824  2022-06-01  08:24  2022-06-01 08:24
# 4    A2022152        0824  2022-06-01  08:24  2022-06-01 08:24
#
#    fire_pixel_confidence fire_pixel_confidence_str  scan_line  grid_sample  \
# 0                      8                         n       2478         1358
# 1                      8                         n       3695           71
# 2                      8                         n       3696           71
# 3                      8                         n       4107          655
# 4                      8                         n       4212          584
#
#    View_Zenith_Angle night/day                     geometry
# 0          51.085258      Both  POINT (-105.04925 62.57816)
# 1          69.029762      Both  POINT (-116.97285 58.58506)
# 2          69.029930      Both  POINT (-116.97173 58.57791)
# 3          60.681606      Both  POINT (-111.05251 57.40565)
# 4          61.619793      Both  POINT (-111.63871 57.04189)

# %% [markdown]
# * export the points to a shapefile

# %%
out_path = "F:\\VIIRS_data\\VIIRS_pnt_no_duplicates"
VIIRS_points_concat.to_file(os.path.join(out_path, "VIIRS_points_no_duplicates.shp")) ## save the VIIRS points to a shapefile
# Out:
# C:\Users\asaf_rs\AppData\Local\Temp\ipykernel_35876\801932299.py:2: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   VIIRS_points_concat.to_file(os.path.join(out_path, "VIIRS_points_no_duplicates.shp")) ## save the VIIRS points to a shapefile
# c:\Users\asaf_rs\miniconda3\envs\goesenv\lib\site-packages\pyogrio\raw.py:709: RuntimeWarning: Normalized/laundered field name: 'Unique_date' to 'Unique_dat'
#   ogr_write(
# c:\Users\asaf_rs\miniconda3\envs\goesenv\lib\site-packages\pyogrio\raw.py:709: RuntimeWarning: Normalized/laundered field name: 'Unique_time' to 'Unique_tim'
#   ogr_write(
# c:\Users\asaf_rs\miniconda3\envs\goesenv\lib\site-packages\pyogrio\raw.py:709: RuntimeWarning: Normalized/laundered field name: 'fire_pixel_confidence' to 'fire_pixel'
#   ogr_write(
# c:\Users\asaf_rs\miniconda3\envs\goesenv\lib\site-packages\pyogrio\raw.py:709: RuntimeWarning: Normalized/laundered field name: 'fire_pixel_confidence_str' to 'fire_pix_1'
#   ogr_write(
# c:\Users\asaf_rs\miniconda3\envs\goesenv\lib\site-packages\pyogrio\raw.py:709: RuntimeWarning: Normalized/laundered field name: 'grid_sample' to 'grid_sampl'
#   ogr_write(
# c:\Users\asaf_rs\miniconda3\envs\goesenv\lib\site-packages\pyogrio\raw.py:709: RuntimeWarning: Normalized/laundered field name: 'View_Zenith_Angle' to 'View_Zenit'
#   ogr_write(

# %%
fire_point_with_dup = []
for i in range(len(VIIRS_files)):
    VIIRS_gdf = generate_VIIRS_points(VIIRS_files[i])
    fire_point_with_dup.append(VIIRS_gdf)
    
fire_point_with_dup_concat = pd.concat(fire_point_with_dup) ## concatenate the points
fire_point_with_dup_concat = fire_point_with_dup_concat[fire_point_with_dup_concat["fire_pixel_confidence"] != 7]
print(f"the number of fire pixels with duplicates: {len(fire_point_with_dup_concat)} and after removing duplicates: {len(VIIRS_points_concat)} this is a difference of {len(fire_point_with_dup_concat) - len(VIIRS_points_concat)} fire pixels") ## print the total number of fire pixels
# Out:
# the number of fire pixels with duplicates: 247383 and after removing duplicates: 227323 this is a difference of 20060 fire pixels
